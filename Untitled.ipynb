# %%
from src.store import DataStore

# Create the store (now using the fixed path)

store = DataStore()



# Ask: "What do you see?"

keys = store.lib.list_symbols()

print(f"\n📂 Vault Inventory ({len(keys)} items):")

print(keys)
# Out:
# 📂 Vault Inventory (18 items):
# ['GOOG_STK', 'MSFT_STK', 'EURUSD_FX', 'GS_STK', 'JPM_STK', 'NZDUSD_FX', 'META_STK', 'MS_STK', 'COP_STK', 'BAC_STK', 'OXY_STK', 'CVX_STK', 'XOM_STK', 'AUDUSD_FX', 'NVDA_STK', 'GBPUSD_FX', 'GOOGL_STK', 'AMD_STK']

# %%
from arcticdb import Arctic
import src.config as config

store = Arctic(config.ARCTIC_PATH)
if "fx.min" in store.list_libraries():
    store.delete_library("fx.min")
    print("🗑️ Cleaned up old fx.min library.")
