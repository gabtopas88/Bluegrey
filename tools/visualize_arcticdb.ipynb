# %% [markdown]
# # Visualise data from ArcticDB
#
# Run these cells from the Bluegrey repo with the `bluegrey` conda environment active.

# %% [markdown]
# Import ArcticDB. Import Path and sys to be able to find src/config.py and import the settings there.

# %%
# --- import ArcticDB module for client setup ---
from arcticdb import Arctic

# --- Modules to manage directories and paths ---
from pathlib import Path # -- for handling filesystem paths
import sys # -- for managing the Python path to ensure project modules can be imported

# --- Ensure repo root is on sys.path so that src/config.py can be imported ---
ROOT_DIR = Path.cwd()

while not (ROOT_DIR / "src").exists(): # -- traverse up the directory tree until we find a directory containing 'src/'
    if ROOT_DIR.parent == ROOT_DIR: # -- if we reach the root of the filesystem without finding 'src/', raise an error and exit to avoid infinite loop
        raise RuntimeError("Could not find repo root containing 'src/'")
    ROOT_DIR = ROOT_DIR.parent

if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR)) # -- add repo root to sys.path at the start (to be read first) for module imports

# --- Now safe to import project config ---
import src.config.config as config

# %% [markdown]
# Connect to the ArcticDB database.

# %%
store = Arctic(config.ARCTIC_PATH)  # -- connect to ArcticDB store using path from config.

# If you run this line more than once you'll get a warning that the store is already initialized. You can ignore that if you're just running this notebook multiple times.

# %% [markdown]
# ## --- Set the market & ticker frequency ---

# %%
# What market do you want to see? i.e. "fx", "equity", "crypto", "options", "indices".
market = "crypto"

# What frequency do you want to see? i.e. "sec", "min", "hour", "day", "week", "month", "quarter", "year".
freq = "hour"

# %% [markdown]
# Build the library name from asset type and frequency.
# <br>
# Load the corresponding dataset from the config.

# %%
# Combine to get the library name, e.g. "fx_min"Arctic
lib_name = f"{market}_{freq}"

lib = store[config.LIBS[lib_name]]  # -- access the specific library for minute-level FX data as defined in config
# Out:
# ---------------------------------------------------------------------------
# KeyNotFoundException                      Traceback (most recent call last)
# File /opt/miniconda3/envs/bluegrey/lib/python3.11/site-packages/arcticdb/arctic.py:140, in Arctic._get_library(self, name, output_format, arrow_string_format_default)
#     139 try:
# --> 140     lib_with_config = self._library_manager.get_library(
#     141         lib_mgr_name, storage_override, native_storage_config=self._library_adapter.native_config()
#     142     )
#     143     lib = NativeVersionStore(
#     144         lib_with_config.library,
#     145         repr(self._library_adapter),
#    (...)    148         runtime_options=runtime_options,
#     149     )
#
# KeyNotFoundException: Not found: [C:crypto.hour]
#
# The above exception was the direct cause of the following exception:
#
# LibraryNotFound                           Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Combine to get the library name, e.g. "fx_min"Arctic
#       2 lib_name = f"{market}_{freq}"
# ----> 4 lib = store[config.LIBS[lib_name]]  # -- access the specific library for minute-level FX data as defined in config
#
# File /opt/miniconda3/envs/bluegrey/lib/python3.11/site-packages/arcticdb/arctic.py:158, in Arctic.__getitem__(self, name)
#     157 def __getitem__(self, name: str):
# --> 158     return self._get_library(name)
#
# File /opt/miniconda3/envs/bluegrey/lib/python3.11/site-packages/arcticdb/arctic.py:151, in Arctic._get_library(self, name, output_format, arrow_string_format_default)
#     143     lib = NativeVersionStore(
#     144         lib_with_config.library,
#     145         repr(self._library_adapter),
#    (...)    148         runtime_options=runtime_options,
#     149     )
#     150 except KeyNotFoundException as ex:
# --> 151     raise LibraryNotFound(name) from ex
#     153 if self._accessed_libs is not None:
#     154     self._accessed_libs.append(lib)
#
# LibraryNotFound: crypto.hour

# %% [markdown]
# See what symbols are in the library

# %%
symbols = sorted(lib.list_symbols()) # -- get sorted list of all symbols in the library
print(symbols)

# # Uncomment the following to see the symbols as an array
# import numpy as np
# np.array(symbols)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 symbols = sorted(lib.list_symbols()) # -- get sorted list of all symbols in the library
#       2 print(symbols)
#       4 # # Uncomment the following to see the symbols as an array
#       5 # import numpy as np
#       6 # np.array(symbols)
#
# NameError: name 'lib' is not defined

# %% [markdown]
# ##  --- Set symbol ---

# %%
# Choose a symbol to visualize, e.g. "C:EURUSD", or "X:BTCUSD" for crypto. Make sure it exists in the library.
# symbol = "C:EURUSD" # -- example for FX
symbol = "X:BTCUSD" # -- example for crypto

# %% [markdown]
# Put the desired data from the Arctic database into a dataframe

# %%
# Fetch the data for the chosen symbol. This will return a DataFrame with columns like 'open', 'high', 'low', 'close', 'volume', etc.
df = lib.read(symbol).data
# df.head()
df
# Out:
#                             open         high          low        close  \
# timestamp
# 2013-11-04 00:00:00    209.74800    211.47000    209.74800    211.30000
# 2013-11-04 01:00:00    211.64000    212.20000    211.64000    212.20000
# 2013-11-04 02:00:00    212.61825    212.81600    211.55854    211.55854
# 2013-11-04 03:00:00    211.54000    211.54000    209.97000    210.70852
# 2013-11-04 04:00:00    210.28920    210.70316    209.40010    210.70095
# ...                          ...          ...          ...          ...
# 2026-04-08 19:00:00  71101.76000  71391.34000  70981.00000  71331.51000
# 2026-04-08 20:00:00  71271.00000  71500.00000  71230.00000  71387.32000
# 2026-04-08 21:00:00  71382.40000  71766.61000  71298.00000  71562.97000
# 2026-04-08 22:00:00  71562.96000  71584.44000  71038.00000  71068.09000
# 2026-04-08 23:00:00  71088.70000  71218.00000  70886.00000  71130.60000
#
#                          volume        vwap
# timestamp
# 2013-11-04 00:00:00    1.146469    210.7808
# 2013-11-04 01:00:00    1.218420    212.0926
# 2013-11-04 02:00:00    0.258348    212.6275
# 2013-11-04 03:00:00    0.958214    211.1656
# 2013-11-04 04:00:00    1.722571    209.6249
# ...                         ...         ...
# 2026-04-08 19:00:00  672.535896  71261.1345
# 2026-04-08 20:00:00  354.546346  71396.8281
# 2026-04-08 21:00:00  556.036091  71593.5581
# 2026-04-08 22:00:00  338.937460  71296.3644
# 2026-04-08 23:00:00  351.379207  71039.9665
#
# [98707 rows x 6 columns]

# %% [markdown]
# Review brief statistics of dataframe

# %%
# --- Read and display basic statistics for the FX data ---
print("Data Summary Statistics:")
print(df.describe())
print("\nData Info:")
print(df.info())
# Out:
# Data Summary Statistics:
#                 open          high            low          close  \
# count   98707.000000   98707.00000   98707.000000   98707.000000
# mean    28710.056451   28861.72535   28570.058640   28711.393725
# std     32267.330637   32391.38895   32153.810372   32268.421542
# min       175.000000     175.00000       0.060000     175.000000
# 25%      3837.075000    3924.59500    3782.240000    3814.325000
# 50%     11810.000000   11896.90000   11722.009408   11809.400000
# 75%     45651.665000   45956.34500   45319.695000   45648.390000
# max    126099.210000  126296.00000  125210.000000  126099.220000
#
#              volume           vwap
# count  98707.000000   98707.000000
# mean    1531.450085   28709.406297
# std     2385.495054   32267.794289
# min        0.000015     175.000000
# 25%      208.606800    3830.973850
# 50%      815.674125   11803.115300
# 75%     1948.943285   45661.260400
# max    66073.019559  125695.431800
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 98707 entries, 2013-11-04 00:00:00 to 2026-04-08 23:00:00
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    98707 non-null  float64
#  1   high    98707 non-null  float64
#  2   low     98707 non-null  float64
#  3   close   98707 non-null  float64
#  4   volume  98707 non-null  float64
#  5   vwap    98707 non-null  float64
# dtypes: float64(6)
# memory usage: 5.3 MB
# None

# %% [markdown]
# Select a certain time-range of data to see

# %%
from pandas import to_datetime as to_datetime

initial_time = "2026-01-01"
final_time = "2026-02-01"
initial_final_range= (to_datetime(initial_time), to_datetime(final_time))

df_range = lib.read(
    symbol,
    date_range = initial_final_range
).data

# df_range.head()
df_range
# Out:
#                          open     high       low     close       volume  \
# timestamp
# 2026-01-01 00:00:00  87497.95  87930.0  87456.10  87650.01   296.245398
# 2026-01-01 01:00:00  87663.50  88117.0  87642.20  87796.09   256.801534
# 2026-01-01 02:00:00  87810.30  88156.0  87666.89  87753.11   306.893146
# 2026-01-01 03:00:00  87764.00  88074.0  87667.26  87696.53   167.924944
# 2026-01-01 04:00:00  87696.53  87907.0  87361.74  87418.55   803.006602
# ...                       ...      ...       ...       ...          ...
# 2026-01-31 20:00:00  77648.30  78171.0  76968.80  77889.11  1347.805084
# 2026-01-31 21:00:00  77896.00  78415.0  77268.78  78204.41  1130.764039
# 2026-01-31 22:00:00  78343.00  78556.0  77881.50  78060.69   845.580281
# 2026-01-31 23:00:00  78085.40  79279.0  77972.00  78648.00  1096.231276
# 2026-02-01 00:00:00  78648.40  79503.0  78552.70  78817.01   712.341611
#
#                            vwap
# timestamp
# 2026-01-01 00:00:00  87604.5657
# 2026-01-01 01:00:00  87788.5330
# 2026-01-01 02:00:00  87837.5991
# 2026-01-01 03:00:00  87770.3679
# 2026-01-01 04:00:00  87481.7569
# ...                         ...
# 2026-01-31 20:00:00  77440.3263
# 2026-01-31 21:00:00  77889.4855
# 2026-01-31 22:00:00  78138.6078
# 2026-01-31 23:00:00  78599.4306
# 2026-02-01 00:00:00  78991.6536
#
# [745 rows x 6 columns]

# %%
# Plot close, rolling MA, and volume using seaborn

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Ensure datetime index
df_range.index = pd.to_datetime(df_range.index)

# Rolling average
ma_window = 20
df_range[f'close_ma_{ma_window}'] = df_range['close'].rolling(window=ma_window).mean()

# Seaborn styling
sns.set_theme(style="darkgrid", context="notebook")

fig, ax1 = plt.subplots(figsize=(12, 6))

# --- Close + MA (seaborn lines) ---
sns.lineplot(
    x=df_range.index,
    y=df_range['close'],
    ax=ax1,
    label='Close',
    linewidth=1.8
)

sns.lineplot(
    x=df_range.index,
    y=df_range[f'close_ma_{ma_window}'],
    ax=ax1,
    label=f'{ma_window}-Period MA',
    linewidth=2.0,
    linestyle='--'
)

ax1.set_xlabel('Date')
ax1.set_ylabel('Close Price')

# --- Volume (secondary axis, matplotlib bar) ---
ax2 = ax1.twinx()
ax2.bar(
    df_range.index,
    df_range['volume'],
    width=0.3,
    alpha=0.25,
    label='Volume'
)
ax2.set_ylabel('Volume')

# Title
ax1.set_title('Close Price, Moving Average, and Volume', fontsize=14, weight='bold')

# Combine legends
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper left')

# Formatting
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
