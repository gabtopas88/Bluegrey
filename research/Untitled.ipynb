# %%
from src.store import DataStore

# Create the store (now using the fixed path)

store = DataStore()



# Ask: "What do you see?"

keys = store.lib.list_symbols()

print(f"\n📂 Vault Inventory ({len(keys)} items):")

print(keys)
# Out:
# 📂 Vault Inventory (18 items):
# ['NVDA_STK', 'EURUSD_FX', 'GOOGL_STK', 'NZDUSD_FX', 'GBPUSD_FX', 'OXY_STK', 'JPM_STK', 'MS_STK', 'COP_STK', 'AUDUSD_FX', 'GS_STK', 'GOOG_STK', 'XOM_STK', 'BAC_STK', 'META_STK', 'CVX_STK', 'MSFT_STK', 'AMD_STK']
