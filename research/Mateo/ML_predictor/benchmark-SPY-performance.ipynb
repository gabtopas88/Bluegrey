# %%
from run_single_case_features_Sharpe import run_single_case_features_Sharpe

# %%
run_single_case_features_Sharpe(
    symbol='SPY', asset_class='STK',
    start_date="2026-01-01", end_date='2026-07-01',
    signal_threshold=0.002,
    n_features=10,
    training_years=10
    )
# Out:
# 🧠 Predicting 2026-06-30 |  123/123 |  last: 0.32s |  elapsed: 51.3s
# ✅ Prediction complete. Took 51.5s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: SPY ML Walk Forward ---
#    Frictionless Return:     -5.23%
#    Net Strategy Return:     -5.63%  (EW Benchmark: 8.68%)
#    Max Drawdown:            -10.96%
#    Win Rate (Gross Bars):   50.0%   (EW Benchmark: 54.9%)
#    Loss Rate (Gross Bars):  48.4%   (EW Benchmark: 45.1%)
#    Zero Rate (Gross Bars):  1.6%    (EW Benchmark: 0.0%)
#    Sharpe Ratio (Net):      -0.81    (EW Benchmark: 1.34)
#    Sortino/√2 (Net):        -0.76    (EW Benchmark: 1.45)
#    Total Fees Paid:         $3,981.87
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/research/Tearsheets/SPY_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)
