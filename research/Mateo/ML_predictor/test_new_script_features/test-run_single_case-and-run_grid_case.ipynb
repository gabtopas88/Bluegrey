# %% [markdown]
# ### RUN_SINGLE_CASE

# %%
from run_single_case import run_single_case

# %%
# If you edit run_single_case.py after importing it:
import importlib
import run_single_case
importlib.reload(run_single_case)
from run_single_case import run_single_case

# %%
run_single_case("BTC-USD", start_date="2020-01-01", end_date="2020-01-31", n_features=9, signal_threshold=0.01, return_params=True)
# Out:
# 🧠 Predicting 2020-01-30 |  30/30 |  last: 3.03s |  elapsed: 2m 21.2s
# ✅ Prediction complete. Took 2m 24.1s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: BTC-USD ML Walk Forward ---
#    Frictionless Return: 9.21%
#    Net Strategy Return: 9.12% (EW Benchmark: 29.48%)
#    Max Drawdown:        -3.81%
#    Win Rate (Bars):     16.7%
#    Total Fees Paid:     $841.56
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/BTC-USD_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)
# {'symbol': 'BTC-USD',
#  'start_date': '2020-01-01',
#  'end_date': '2020-01-31',
#  'signal_threshold': 0.01,
#  'n_features': 9,
#  'training_years': 5,
#  'position_size': 1.0,
#  'max_iter': 5000,
#  'verbose': False,
#  'show_progress': True}

# %% [markdown]
# ### PARAMETER_GRID_SEARCH

# %%
from run_grid_case import parameter_grid_search

# %%
# If you edit run_grid_case.py after importing it:
import importlib
import run_grid_case
importlib.reload(run_grid_case)
from run_grid_case import parameter_grid_search

# %%
parameter_grid_search(symbol="ECH", var_1="n_features", list_1=[7, 8], var_2="signal_threshold", list_2=[0.001, 0.003], start_date="2018-01-01", end_date="2018-01-10")
# Out:
#   symbol  start_date    end_date  signal_threshold  n_features  \
# 0    ECH  2018-01-01  2018-01-10             0.001           7
# 1    ECH  2018-01-01  2018-01-10             0.003           7
# 2    ECH  2018-01-01  2018-01-10             0.001           8
# 3    ECH  2018-01-01  2018-01-10             0.003           8
#
#    training_years  position_size  max_iter  verbose  show_progress  \
# 0               5            1.0      5000    False          False
# 1               5            1.0      5000    False          False
# 2               5            1.0      5000    False          False
# 3               5            1.0      5000    False          False
#
#    net_return_pct  gross_return_pct  final_net_equity  final_gross_equity
# 0        3.473386          3.518368      1.034734e+06        1.035184e+06
# 1        3.134812          3.179670      1.031348e+06        1.031797e+06
# 2        3.888567          4.016678      1.038886e+06        1.040167e+06
# ...

# %%
parameter_grid_search(symbol="ECH", var_1="n_features", list_1=[7, 8], var_2="signal_threshold", list_2=[0.001, 0.003], start_date="2018-01-01", end_date="2018-01-10", n_jobs=1)
# Out:
#   symbol  start_date    end_date  signal_threshold  n_features  \
# 0    ECH  2018-01-01  2018-01-10             0.001           7
# 1    ECH  2018-01-01  2018-01-10             0.003           7
# 2    ECH  2018-01-01  2018-01-10             0.001           8
# 3    ECH  2018-01-01  2018-01-10             0.003           8
#
#    training_years  position_size  max_iter  verbose  show_progress  \
# 0               5            1.0      5000    False          False
# 1               5            1.0      5000    False          False
# 2               5            1.0      5000    False          False
# 3               5            1.0      5000    False          False
#
#    net_return_pct  gross_return_pct  final_net_equity  final_gross_equity
# 0        3.473386          3.518368      1.034734e+06        1.035184e+06
# 1        3.134812          3.179670      1.031348e+06        1.031797e+06
# 2        3.888567          4.016678      1.038886e+06        1.040167e+06
# ...

# %%
parameter_grid_search(symbol="ECH", var_1="n_features", list_1=[7, 8], var_2="signal_threshold", list_2=[0.001, 0.003], start_date="2018-01-01", end_date="2018-01-10", n_jobs=2)
# Out:
#   symbol  start_date    end_date  signal_threshold  n_features  \
# 0    ECH  2018-01-01  2018-01-10             0.001           7
# 1    ECH  2018-01-01  2018-01-10             0.003           7
# 2    ECH  2018-01-01  2018-01-10             0.001           8
# 3    ECH  2018-01-01  2018-01-10             0.003           8
#
#    training_years  position_size  max_iter  verbose  show_progress  \
# 0               5            1.0      5000    False          False
# 1               5            1.0      5000    False          False
# 2               5            1.0      5000    False          False
# 3               5            1.0      5000    False          False
#
#    net_return_pct  gross_return_pct  final_net_equity  final_gross_equity
# 0        3.473386          3.518368      1.034734e+06        1.035184e+06
# 1        3.134812          3.179670      1.031348e+06        1.031797e+06
# 2        3.888567          4.016678      1.038886e+06        1.040167e+06
# ...
