# %%
from run_single_case_features_Sharpe import run_single_case_features_Sharpe
from run_single_case import run_single_case

def play_sound(name="Glass"):
    import subprocess
    subprocess.run(["afplay", f"/System/Library/Sounds/{name}.aiff"])

play_sound()

# %%
run_single_case(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2025-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 12,
    position_size = 1.0,
    initial_capital = 1000000,
    max_iter = 5000,
    verbose = False,
    show_progress = True,
)
# Out:
# 🧠 Predicting 2025-12-31 |  250/250 |  last: 0.15s |  elapsed: 37.4s
# ✅ Prediction complete. Took 37.5s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 45.17%
#    Net Strategy Return: 39.94% (EW Benchmark: 65.17%)
#    Max Drawdown:        -13.31%
#    Win Rate (Gross Bars):     54.8% (EW Benchmark (Bars): 54.4%)
#    Loss Rate (Gross Bars):    42.0% (EW Benchmark (Bars): 42.8%)
#    Total Fees Paid:     $52,244.29
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %% [markdown]
# Ran the above cell with the new computer.
#
# It now takes 37.5s to do a job that the old computer took 2m 1.6s.
#
# > 3x faster!!

# %%
run_single_case(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2020-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 12,
    position_size = 1.0,
    initial_capital = 1000000,
    max_iter = 5000,
    verbose = False,
    show_progress = True,
)
# Out:
# 🧠 Predicting 2025-12-31 |  1508/1508 |  last: 0.16s |  elapsed: 3m 11.6s658/1508 |  last: 0.09s |  elapsed: 1m 10.9s 1246/1508 |  last: 0.20s |  elapsed: 2m 30.1s
# ✅ Prediction complete. Took 3m 11.7s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 309.67%
#    Net Strategy Return: 233.78% (EW Benchmark: 51.31%)
#    Max Drawdown:        -45.07%
#    Win Rate (Gross Bars):     49.1% (EW Benchmark (Bars): 50.6%)
#    Loss Rate (Gross Bars):    43.1% (EW Benchmark (Bars): 48.1%)
#    Total Fees Paid:     $758,915.12
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %% [markdown]
# Ran the above cell with the new computer.
#
# It now takes 3m 11.7s to do a job that the old computer took 56m 33s.
#
# > 17x faster!!

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2020-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 12,
    position_size = 1.0,
    initial_capital = 1000000,
    max_iter = 5000,
    verbose = False,
    show_progress = True,
)
# Out:
# 🧠 Predicting 2025-12-31 |  1508/1508 |  last: 0.16s |  elapsed: 3m 16.3s/1508 |  last: 0.09s |  elapsed: 46.2s 660/1508 |  last: 0.09s |  elapsed: 1m 11.9s 1467/1508 |  last: 0.20s |  elapsed: 3m 8.9s
# ✅ Prediction complete. Took 3m 16.4s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 178.95%
#    Net Strategy Return: 149.39% (EW Benchmark: 51.31%)
#    Max Drawdown:        -34.29%
#    Win Rate (Gross Bars):     23.6% (EW Benchmark (Bars): 50.6%)
#    Loss Rate (Gross Bars):    20.3% (EW Benchmark (Bars): 48.1%)
#    Total Fees Paid:     $295,652.84
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %% [markdown]
# Ran the above cell with the new computer.
#
# It now takes 3m 16.4s to do a job that the old computer took 56m 45s.
#
# > 17x faster!!

# %%
play_sound()

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2021-10-01",
    end_date = "2022-02-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 12,
    # rolling_sharpe_window = 21,
)
# Out:
# 🧠 Predicting 2022-01-31 |  84/84 |  last: 0.16s |  elapsed: 9.8s9/84 |  last: 0.09s |  elapsed: 0.8s
# ✅ Prediction complete. Took 9.9s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: -3.21%
#    Net Strategy Return: -3.76% (EW Benchmark: 1.04%)
#    Max Drawdown:        -6.78%
#    Win Rate (Gross Bars):     8.3% (EW Benchmark (Bars): 42.9%)
#    Loss Rate (Gross Bars):    10.7% (EW Benchmark (Bars): 54.8%)
#    Total Fees Paid:     $5,464.52
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2021-10-01",
    end_date = "2022-02-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 12,
)
# Out:
# 🧠 Predicting 2022-01-31 |  84/84 |  last: 2.03s |  elapsed: 1m 53.3s
# ✅ Prediction complete. Took 1m 54.6s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 20.47%
#    Net Strategy Return: 17.96% (EW Benchmark: 1.04%)
#    Max Drawdown:        -26.56%
#    Win Rate (Gross Bars):     47.6% (EW Benchmark (Bars): 42.9%)
#    Loss Rate (Gross Bars):    48.8% (EW Benchmark (Bars): 54.8%)
#    Total Fees Paid:     $25,103.26
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2021-10-01",
    end_date = "2022-02-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 12,
    rolling_sharpe_window = 21,
)
# Out:
# 🧠 Predicting 2022-01-31 |  84/84 |  last: 2.01s |  elapsed: 2m 0.3ss
# ✅ Prediction complete. Took 2m 2.2s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 19.92%
#    Net Strategy Return: 18.87% (EW Benchmark: 1.04%)
#    Max Drawdown:        -20.11%
#    Win Rate (Gross Bars):     21.4% (EW Benchmark (Bars): 42.9%)
#    Loss Rate (Gross Bars):    19.0% (EW Benchmark (Bars): 54.8%)
#    Total Fees Paid:     $10,573.11
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2021-10-01",
    end_date = "2022-02-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 12,
    rolling_sharpe_window = 15,
)
# Out:
# 🧠 Predicting 2022-01-31 |  84/84 |  last: 2.57s |  elapsed: 2m 8.4ss
# ✅ Prediction complete. Took 2m 9.9s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 32.44%
#    Net Strategy Return: 31.26% (EW Benchmark: 1.04%)
#    Max Drawdown:        -9.24%
#    Win Rate (Gross Bars):     23.8% (EW Benchmark (Bars): 42.9%)
#    Loss Rate (Gross Bars):    19.0% (EW Benchmark (Bars): 54.8%)
#    Total Fees Paid:     $11,761.27
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2020-10-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 12,
    rolling_sharpe_window = 15,
)
# Out:
# 🧠 Predicting 2025-12-31 |  1319/1319 |  last: 2.56s |  elapsed: 50m 45.3s
# ✅ Prediction complete. Took 50m 47.5s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 92.37%
#    Net Strategy Return: 66.86% (EW Benchmark: 104.87%)
#    Max Drawdown:        -44.63%
#    Win Rate (Gross Bars):     23.7% (EW Benchmark (Bars): 50.8%)
#    Loss Rate (Gross Bars):    22.5% (EW Benchmark (Bars): 47.8%)
#    Total Fees Paid:     $255,179.75
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2020-10-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 12,
    rolling_sharpe_window = 10,
)
# Out:
# 🧠 Predicting 2025-12-31 |  1319/1319 |  last: 2.34s |  elapsed: 46m 26.3s
# ✅ Prediction complete. Took 46m 28.3s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 126.01%
#    Net Strategy Return: 97.37% (EW Benchmark: 104.87%)
#    Max Drawdown:        -33.54%
#    Win Rate (Gross Bars):     25.5% (EW Benchmark (Bars): 50.8%)
#    Loss Rate (Gross Bars):    22.6% (EW Benchmark (Bars): 47.8%)
#    Total Fees Paid:     $286,439.91
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
# Nearly as good in the same high-feature family: net_return_pct = 38.83%
ech_best_params_2 = {
    "symbol": "ECH",
    "asset_class": "STK",
    "start_date": "2025-01-01",
    "end_date": "2026-01-01",
    "signal_threshold": 0.002,
    "n_features": 10,
    "training_years": 8,
    "position_size": 1.0,
    "initial_capital": 1000000,
    "max_iter": 5000,
    "verbose": False,
    "show_progress": True,
}

# %%
run_single_case(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2025-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 8,
    )
# Out:
# 🧠 Predicting 2025-12-31 |  250/250 |  last: 0.34s |  elapsed: 1m 31.6s
# ✅ Prediction complete. Took 1m 32.0s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 53.46%
#    Net Strategy Return: 47.42% (EW Benchmark: 65.17%)
#    Max Drawdown:        -15.62%
#    Win Rate (Gross Bars):     53.6% (EW Benchmark (Bars): 54.4%)
#    Loss Rate (Gross Bars):    43.2% (EW Benchmark (Bars): 42.8%)
#    Total Fees Paid:     $60,366.96
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2025-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 8,
    rolling_sharpe_window = 10,
)
# Out:
# 🧠 Predicting 2025-12-31 |  250/250 |  last: 0.29s |  elapsed: 1m 14.5s
# ✅ Prediction complete. Took 1m 14.9s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 46.11%
#    Net Strategy Return: 42.01% (EW Benchmark: 65.17%)
#    Max Drawdown:        -7.26%
#    Win Rate (Gross Bars):     34.0% (EW Benchmark (Bars): 54.4%)
#    Loss Rate (Gross Bars):    28.8% (EW Benchmark (Bars): 42.8%)
#    Total Fees Paid:     $41,024.63
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2025-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 8,
    rolling_sharpe_window = 5,
)
# Out:
# 🧠 Predicting 2025-12-31 |  250/250 |  last: 0.29s |  elapsed: 1m 16.8s
# ✅ Prediction complete. Took 1m 17.2s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 34.33%
#    Net Strategy Return: 30.24% (EW Benchmark: 65.17%)
#    Max Drawdown:        -11.12%
#    Win Rate (Gross Bars):     30.0% (EW Benchmark (Bars): 54.4%)
#    Loss Rate (Gross Bars):    25.2% (EW Benchmark (Bars): 42.8%)
#    Total Fees Paid:     $40,940.37
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2025-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 8,
    rolling_sharpe_window = 10,
    sharpe_enter_threshold = 1.55,
    sharpe_exit_threshold = 1.45,
)
# Out:
# 🧠 Predicting 2025-12-31 |  250/250 |  last: 0.32s |  elapsed: 1m 21.9s50 |  last: 0.20s |  elapsed: 3.1s
# ✅ Prediction complete. Took 1m 22.4s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 45.26%
#    Net Strategy Return: 41.21% (EW Benchmark: 65.17%)
#    Max Drawdown:        -6.66%
#    Win Rate (Gross Bars):     33.2% (EW Benchmark (Bars): 54.4%)
#    Loss Rate (Gross Bars):    28.0% (EW Benchmark (Bars): 42.8%)
#    Total Fees Paid:     $40,560.19
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2025-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 8,
    rolling_sharpe_window = 10,
    sharpe_enter_threshold = 2.00,
    sharpe_exit_threshold = 2.00,
)
# Out:
# 🧠 Predicting 2025-12-31 |  250/250 |  last: 0.33s |  elapsed: 1m 19.2s
# ✅ Prediction complete. Took 1m 19.6s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 44.48%
#    Net Strategy Return: 40.58% (EW Benchmark: 65.17%)
#    Max Drawdown:        -7.07%
#    Win Rate (Gross Bars):     30.4% (EW Benchmark (Bars): 54.4%)
#    Loss Rate (Gross Bars):    25.6% (EW Benchmark (Bars): 42.8%)
#    Total Fees Paid:     $38,944.46
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2025-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 8,
    rolling_sharpe_window = 20,
    sharpe_enter_threshold = 2.00,
    sharpe_exit_threshold = 2.00,
)
# Out:
# 🧠 Predicting 2025-12-31 |  250/250 |  last: 0.30s |  elapsed: 1m 21.5s
# ✅ Prediction complete. Took 1m 21.9s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 40.36%
#    Net Strategy Return: 36.86% (EW Benchmark: 65.17%)
#    Max Drawdown:        -6.77%
#    Win Rate (Gross Bars):     30.0% (EW Benchmark (Bars): 54.4%)
#    Loss Rate (Gross Bars):    25.2% (EW Benchmark (Bars): 42.8%)
#    Total Fees Paid:     $35,017.13
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2018-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 8,
    rolling_sharpe_window = 10,
    sharpe_enter_threshold = 2.00,
    sharpe_exit_threshold = 2.00,
)
# Out:
# 🧠 Predicting 2025-12-31 |  2011/2011 |  last: 0.28s |  elapsed: 8m 8.1ss374/2011 |  last: 0.20s |  elapsed: 1m 41.5s 386/2011 |  last: 0.20s |  elapsed: 1m 44.5s 429/2011 |  last: 0.20s |  elapsed: 1m 54.0s 839/2011 |  last: 0.20s |  elapsed: 3m 25.5s 1203/2011 |  last: 0.20s |  elapsed: 4m 43.7s 1415/2011 |  last: 0.20s |  elapsed: 5m 34.2s 1427/2011 |  last: 0.21s |  elapsed: 5m 37.1s 1588/2011 |  last: 0.20s |  elapsed: 6m 15.0s
# ✅ Prediction complete. Took 8m 8.4s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 67.11%
#    Net Strategy Return: 42.26% (EW Benchmark: 0.09%)
#    Max Drawdown:        -46.95%
#    Win Rate (Gross Bars):     22.0% (EW Benchmark (Bars): 49.2%)
#    Loss Rate (Gross Bars):    20.6% (EW Benchmark (Bars): 49.6%)
#    Total Fees Paid:     $248,485.24
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ...

# %%
run_single_case_features_Sharpe(
    symbol = "ECH",
    asset_class = "STK",
    start_date = "2018-01-01",
    end_date = "2026-01-01",
    signal_threshold = 0.002,
    n_features = 10,
    training_years = 8,
    rolling_sharpe_window = 126,
    sharpe_enter_threshold = 2.00,
    sharpe_exit_threshold = 2.00,
)
# Out:
# 🧠 Predicting 2025-12-31 |  2011/2011 |  last: 0.27s |  elapsed: 8m 15.9s/2011 |  last: 0.20s |  elapsed: 54.8s 346/2011 |  last: 0.20s |  elapsed: 1m 32.0s 905/2011 |  last: 0.20s |  elapsed: 3m 46.8s 1015/2011 |  last: 0.20s |  elapsed: 4m 12.1s 1268/2011 |  last: 0.20s |  elapsed: 5m 9.4s 1353/2011 |  last: 0.20s |  elapsed: 5m 29.4s 1405/2011 |  last: 0.20s |  elapsed: 5m 41.8s 1563/2011 |  last: 0.20s |  elapsed: 6m 18.0s 1909/2011 |  last: 0.20s |  elapsed: 7m 45.2s
# ✅ Prediction complete. Took 8m 16.2s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 20.04%
#    Net Strategy Return: 7.72% (EW Benchmark: 0.09%)
#    Max Drawdown:        -34.04%
#    Win Rate (Gross Bars):     13.5% (EW Benchmark (Bars): 49.2%)
#    Loss Rate (Gross Bars):    11.6% (EW Benchmark (Bars): 49.6%)
#    Total Fees Paid:     $123,214.85
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ...

# %% [markdown]
# I found that `training_years = 10` produces very good returns for `20222–2025` inclusive for high `n_features`, the best combination being `n_features = 13` and `signal_threshold = 0.02` -> net return 106.9%, and second best `n_features = 15` and `signal_threshold = 0.03` -> net return 101.7%.
#
# Both of these perform very close to `ECH` buy-hold -> 104.5%

# %%
run_single_case(symbol="ECH",
        asset_class="STK",
        start_date="2022-01-01",
        end_date="2026-01-01",
        n_features = 13,
        signal_threshold = 0.002,
        training_years = 10,
)
# Out:
# 🧠 Predicting 2025-12-31 |  1003/1003 |  last: 0.58s |  elapsed: 10m 35.8s
# ✅ Prediction complete. Took 10m 36.2s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 138.84%
#    Net Strategy Return: 106.85% (EW Benchmark: 104.54%)
#    Max Drawdown:        -41.36%
#    Win Rate (Gross Bars):     52.1% (EW Benchmark (Bars): 51.2%)
#    Loss Rate (Gross Bars):    46.5% (EW Benchmark (Bars): 47.5%)
#    Total Fees Paid:     $319,860.19
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)

# %%
run_single_case_features_Sharpe(symbol="ECH", asset_class="STK",
        start_date="2022-01-01",
        end_date="2026-01-01",
        n_features = 13,
        signal_threshold = 0.002,
        training_years = 10,
        rolling_sharpe_window = 30,
        sharpe_enter_threshold = 1.00,
        sharpe_exit_threshold = 1.00,     
)
# Out:
# 🧠 Predicting 2025-12-31 |  1003/1003 |  last: 0.68s |  elapsed: 11m 7.5s
# ✅ Prediction complete. Took 11m 8.1s
#
#
# 📊 --- QUICK PORTFOLIO RESULTS: ECH ML Walk Forward ---
#    Frictionless Return: 52.29%
#    Net Strategy Return: 38.32% (EW Benchmark: 104.54%)
#    Max Drawdown:        -25.87%
#    Win Rate (Gross Bars):     26.3% (EW Benchmark (Bars): 51.2%)
#    Loss Rate (Gross Bars):    24.2% (EW Benchmark (Bars): 47.5%)
#    Total Fees Paid:     $139,719.30
# ---------------------------------------------
# 📈 Generating Institutional Tearsheet (quantstats)...
# ✅ Tearsheet saved successfully to: /Users/mateo/Bluegrey/src/research/Tearsheets/ECH_ML_Walk_Forward_tearsheet.html
#    (Open this file in your web browser to view Sharpe, Drawdowns, etc.)
